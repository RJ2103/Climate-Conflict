# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Load Dataset

df = pd.read_csv("C:\Users\Admin\Desktop\TheObservable\Climate-Conflict\data\processed\temperature_conflict_merged_annual.csv")
